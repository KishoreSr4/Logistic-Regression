# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
data=pd.read_csv("C:/Users/abc/Desktop/Data Science/Assignments/Logistic Regression/bank-full.csv",sep=";")

# %%
data
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# As we can see some columns need to be converted to numerical format

# %%
data["job"].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data["job"].replace({
    "unknown":np.nan,
    "management":0,
    "technician":1,
    "entrepreneur":2,
    "blue-collar":3,
    "retired":4,
    "admin":5,
    "services":6,
    "self-employed":7,
    "unemployed":8,
    "housemaid":9,
    "student":10
},inplace=True)

# %%
data.head()
# Out:
#    age  job  marital  education default  balance housing loan  contact  day  \
# 0   58    0  married   tertiary      no     2143     yes   no  unknown    5
# 1   44    1   single  secondary      no       29     yes   no  unknown    5
# 2   33    2  married  secondary      no        2     yes  yes  unknown    5
# 3   47    3  married    unknown      no     1506     yes   no  unknown    5
# 4   33  NaN   single    unknown      no        1      no   no  unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y
# 0   may       261         1     -1         0  unknown  no
# 1   may       151         1     -1         0  unknown  no
# 2   may        76         1     -1         0  unknown  no
# 3   may        92         1     -1         0  unknown  no
# 4   may       198         1     -1         0  unknown  no

# %%
data["job"].unique()
# Out:
# array([0, 1, 2, 3, nan, 4, 'admin.', 6, 7, 8, 9, 10], dtype=object)

# %% [markdown]
# here i converted the job column to numeric format and confirmed there are no any other categorical format
#
# now lets convert all the columns

# %%
data["marital"].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
data["marital"].replace({
    "married":1,
    "single":0,
    "divorced":2
    
},inplace=True)

# %%
data
# Out:
#        age  job  marital  education default  balance housing loan    contact  \
# 0       58    0        1   tertiary      no     2143     yes   no    unknown
# 1       44    1        0  secondary      no       29     yes   no    unknown
# 2       33    2        1  secondary      no        2     yes  yes    unknown
# 3       47    3        1    unknown      no     1506     yes   no    unknown
# 4       33  NaN        0    unknown      no        1      no   no    unknown
# ...    ...  ...      ...        ...     ...      ...     ...  ...        ...
# 45206   51    1        1   tertiary      no      825      no   no   cellular
# 45207   71    4        2    primary      no     1729      no   no   cellular
# 45208   72    4        1  secondary      no     5715      no   no   cellular
# 45209   57    3        1  secondary      no      668      no   no  telephone
# 45210   37    2        1  secondary      no     2971      no   no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# 0        5   may       261         1     -1         0  unknown   no
# 1        5   may       151         1     -1         0  unknown   no
# 2        5   may        76         1     -1         0  unknown   no
# 3        5   may        92         1     -1         0  unknown   no
# 4        5   may       198         1     -1         0  unknown   no
# ...    ...   ...       ...       ...    ...       ...      ...  ...
# 45206   17   nov       977         3     -1         0  unknown  yes
# 45207   17   nov       456         2     -1         0  unknown  yes
# 45208   17   nov      1127         5    184         3  success  yes
# 45209   17   nov       508         4     -1         0  unknown   no
# 45210   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["marital"].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
data["education"].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
data["education"].replace({
    "unknown":np.nan,
    "primary":0,
    "secondary":1,
    "tertiary":2
    
},inplace=True)

# %%
data["education"].unique()
# Out:
# array([ 2.,  1., nan,  0.])

# %%
data
# Out:
#        age  job  marital  education default  balance housing loan    contact  \
# 0       58    0        1        2.0      no     2143     yes   no    unknown
# 1       44    1        0        1.0      no       29     yes   no    unknown
# 2       33    2        1        1.0      no        2     yes  yes    unknown
# 3       47    3        1        NaN      no     1506     yes   no    unknown
# 4       33  NaN        0        NaN      no        1      no   no    unknown
# ...    ...  ...      ...        ...     ...      ...     ...  ...        ...
# 45206   51    1        1        2.0      no      825      no   no   cellular
# 45207   71    4        2        0.0      no     1729      no   no   cellular
# 45208   72    4        1        1.0      no     5715      no   no   cellular
# 45209   57    3        1        1.0      no      668      no   no  telephone
# 45210   37    2        1        1.0      no     2971      no   no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# 0        5   may       261         1     -1         0  unknown   no
# 1        5   may       151         1     -1         0  unknown   no
# 2        5   may        76         1     -1         0  unknown   no
# 3        5   may        92         1     -1         0  unknown   no
# 4        5   may       198         1     -1         0  unknown   no
# ...    ...   ...       ...       ...    ...       ...      ...  ...
# 45206   17   nov       977         3     -1         0  unknown  yes
# 45207   17   nov       456         2     -1         0  unknown  yes
# 45208   17   nov      1127         5    184         3  success  yes
# 45209   17   nov       508         4     -1         0  unknown   no
# 45210   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["default"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["default"].replace({
    "no":0,
    "yes":1
},inplace=True)

# %%
data["default"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data
# Out:
#        age  job  marital  education  default  balance housing loan    contact  \
# 0       58    0        1        2.0        0     2143     yes   no    unknown
# 1       44    1        0        1.0        0       29     yes   no    unknown
# 2       33    2        1        1.0        0        2     yes  yes    unknown
# 3       47    3        1        NaN        0     1506     yes   no    unknown
# 4       33  NaN        0        NaN        0        1      no   no    unknown
# ...    ...  ...      ...        ...      ...      ...     ...  ...        ...
# 45206   51    1        1        2.0        0      825      no   no   cellular
# 45207   71    4        2        0.0        0     1729      no   no   cellular
# 45208   72    4        1        1.0        0     5715      no   no   cellular
# 45209   57    3        1        1.0        0      668      no   no  telephone
# 45210   37    2        1        1.0        0     2971      no   no   cellular
#
#        day month  duration  campaign  pdays  previous poutcome    y
# 0        5   may       261         1     -1         0  unknown   no
# 1        5   may       151         1     -1         0  unknown   no
# 2        5   may        76         1     -1         0  unknown   no
# 3        5   may        92         1     -1         0  unknown   no
# 4        5   may       198         1     -1         0  unknown   no
# ...    ...   ...       ...       ...    ...       ...      ...  ...
# 45206   17   nov       977         3     -1         0  unknown  yes
# 45207   17   nov       456         2     -1         0  unknown  yes
# 45208   17   nov      1127         5    184         3  success  yes
# 45209   17   nov       508         4     -1         0  unknown   no
# 45210   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["housing"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data["housing"].replace({
    "no":0,
    "yes":1
},inplace=True)

# %%
data["housing"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing loan  \
# 0       58    0        1        2.0        0     2143        1   no
# 1       44    1        0        1.0        0       29        1   no
# 2       33    2        1        1.0        0        2        1  yes
# 3       47    3        1        NaN        0     1506        1   no
# 4       33  NaN        0        NaN        0        1        0   no
# ...    ...  ...      ...        ...      ...      ...      ...  ...
# 45206   51    1        1        2.0        0      825        0   no
# 45207   71    4        2        0.0        0     1729        0   no
# 45208   72    4        1        1.0        0     5715        0   no
# 45209   57    3        1        1.0        0      668        0   no
# 45210   37    2        1        1.0        0     2971        0   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["loan"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["loan"].replace({
    "no":0,
    "yes":1
},inplace=True)

# %%
data["loan"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing  loan  \
# 0       58    0        1        2.0        0     2143        1     0
# 1       44    1        0        1.0        0       29        1     0
# 2       33    2        1        1.0        0        2        1     1
# 3       47    3        1        NaN        0     1506        1     0
# 4       33  NaN        0        NaN        0        1        0     0
# ...    ...  ...      ...        ...      ...      ...      ...   ...
# 45206   51    1        1        2.0        0      825        0     0
# 45207   71    4        2        0.0        0     1729        0     0
# 45208   72    4        1        1.0        0     5715        0     0
# 45209   57    3        1        1.0        0      668        0     0
# 45210   37    2        1        1.0        0     2971        0     0
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["contact"].unique()
# Out:
# array(['unknown', 'cellular', 'telephone'], dtype=object)

# %%
data["contact"].replace({
    "unknown":np.nan,
    "cellular":0,
    "telephone":1
},inplace=True)

# %%
data["contact"].unique()
# Out:
# array([nan,  0.,  1.])

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    0        1        2.0        0     2143        1     0      NaN
# 1       44    1        0        1.0        0       29        1     0      NaN
# 2       33    2        1        1.0        0        2        1     1      NaN
# 3       47    3        1        NaN        0     1506        1     0      NaN
# 4       33  NaN        0        NaN        0        1        0     0      NaN
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    1        1        2.0        0      825        0     0      0.0
# 45207   71    4        2        0.0        0     1729        0     0      0.0
# 45208   72    4        1        1.0        0     5715        0     0      0.0
# 45209   57    3        1        1.0        0      668        0     0      1.0
# 45210   37    2        1        1.0        0     2971        0     0      0.0
#
#        day month  duration  campaign  pdays  previous poutcome    y
# 0        5   may       261         1     -1         0  unknown   no
# 1        5   may       151         1     -1         0  unknown   no
# 2        5   may        76         1     -1         0  unknown   no
# 3        5   may        92         1     -1         0  unknown   no
# 4        5   may       198         1     -1         0  unknown   no
# ...    ...   ...       ...       ...    ...       ...      ...  ...
# 45206   17   nov       977         3     -1         0  unknown  yes
# 45207   17   nov       456         2     -1         0  unknown  yes
# 45208   17   nov      1127         5    184         3  success  yes
# 45209   17   nov       508         4     -1         0  unknown   no
# 45210   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["month"].unique()
# Out:
# array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'jan', 'feb',
#        'mar', 'apr', 'sep'], dtype=object)

# %%
data["month"].replace({
    "jan":1,
    "feb":2,
    "mar":3,
    "apr":4,
    "may":5,
    "jun":6,
    "jul":7,
    "aug":8,
    "sep":9,
    "oct":10,
    "nov":11,
    "dec":12
},inplace=True)

# %%
data["month"].unique()
# Out:
# array([ 5,  6,  7,  8, 10, 11, 12,  1,  2,  3,  4,  9], dtype=int64)

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    0        1        2.0        0     2143        1     0      NaN
# 1       44    1        0        1.0        0       29        1     0      NaN
# 2       33    2        1        1.0        0        2        1     1      NaN
# 3       47    3        1        NaN        0     1506        1     0      NaN
# 4       33  NaN        0        NaN        0        1        0     0      NaN
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    1        1        2.0        0      825        0     0      0.0
# 45207   71    4        2        0.0        0     1729        0     0      0.0
# 45208   72    4        1        1.0        0     5715        0     0      0.0
# 45209   57    3        1        1.0        0      668        0     0      1.0
# 45210   37    2        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous poutcome    y
# 0        5      5       261         1     -1         0  unknown   no
# 1        5      5       151         1     -1         0  unknown   no
# 2        5      5        76         1     -1         0  unknown   no
# 3        5      5        92         1     -1         0  unknown   no
# 4        5      5       198         1     -1         0  unknown   no
# ...    ...    ...       ...       ...    ...       ...      ...  ...
# 45206   17     11       977         3     -1         0  unknown  yes
# 45207   17     11       456         2     -1         0  unknown  yes
# 45208   17     11      1127         5    184         3  success  yes
# 45209   17     11       508         4     -1         0  unknown   no
# 45210   17     11       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
data["poutcome"].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
data["poutcome"].replace({
    "unknown":np.nan,
    "failure":0,
    "other":1,
    "success":2
},inplace=True)

# %%
data["poutcome"].unique()
# Out:
# array([nan,  0.,  1.,  2.])

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    0        1        2.0        0     2143        1     0      NaN
# 1       44    1        0        1.0        0       29        1     0      NaN
# 2       33    2        1        1.0        0        2        1     1      NaN
# 3       47    3        1        NaN        0     1506        1     0      NaN
# 4       33  NaN        0        NaN        0        1        0     0      NaN
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    1        1        2.0        0      825        0     0      0.0
# 45207   71    4        2        0.0        0     1729        0     0      0.0
# 45208   72    4        1        1.0        0     5715        0     0      0.0
# 45209   57    3        1        1.0        0      668        0     0      1.0
# 45210   37    2        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome    y
# 0        5      5       261         1     -1         0       NaN   no
# 1        5      5       151         1     -1         0       NaN   no
# 2        5      5        76         1     -1         0       NaN   no
# 3        5      5        92         1     -1         0       NaN   no
# 4        5      5       198         1     -1         0       NaN   no
# ...    ...    ...       ...       ...    ...       ...       ...  ...
# 45206   17     11       977         3     -1         0       NaN  yes
# 45207   17     11       456         2     -1         0       NaN  yes
# 45208   17     11      1127         5    184         3       2.0  yes
# 45209   17     11       508         4     -1         0       NaN   no
# 45210   17     11       361         2    188        11       1.0   no
#
# [45211 rows x 17 columns]

# %%
data["y"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data["y"].replace({
    "no":0,
    "yes":1
},inplace=True)

# %%
data["y"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    0        1        2.0        0     2143        1     0      NaN
# 1       44    1        0        1.0        0       29        1     0      NaN
# 2       33    2        1        1.0        0        2        1     1      NaN
# 3       47    3        1        NaN        0     1506        1     0      NaN
# 4       33  NaN        0        NaN        0        1        0     0      NaN
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    1        1        2.0        0      825        0     0      0.0
# 45207   71    4        2        0.0        0     1729        0     0      0.0
# 45208   72    4        1        1.0        0     5715        0     0      0.0
# 45209   57    3        1        1.0        0      668        0     0      1.0
# 45210   37    2        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      5       261         1     -1         0       NaN  0
# 1        5      5       151         1     -1         0       NaN  0
# 2        5      5        76         1     -1         0       NaN  0
# 3        5      5        92         1     -1         0       NaN  0
# 4        5      5       198         1     -1         0       NaN  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17     11       977         3     -1         0       NaN  1
# 45207   17     11       456         2     -1         0       NaN  1
# 45208   17     11      1127         5    184         3       2.0  1
# 45209   17     11       508         4     -1         0       NaN  0
# 45210   17     11       361         2    188        11       1.0  0
#
# [45211 rows x 17 columns]

# %% [markdown]
# we have converted all the categorical values to numerical value

# %%
data1=data.copy()

# %%
data1
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    0        1        2.0        0     2143        1     0      NaN
# 1       44    1        0        1.0        0       29        1     0      NaN
# 2       33    2        1        1.0        0        2        1     1      NaN
# 3       47    3        1        NaN        0     1506        1     0      NaN
# 4       33  NaN        0        NaN        0        1        0     0      NaN
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    1        1        2.0        0      825        0     0      0.0
# 45207   71    4        2        0.0        0     1729        0     0      0.0
# 45208   72    4        1        1.0        0     5715        0     0      0.0
# 45209   57    3        1        1.0        0      668        0     0      1.0
# 45210   37    2        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      5       261         1     -1         0       NaN  0
# 1        5      5       151         1     -1         0       NaN  0
# 2        5      5        76         1     -1         0       NaN  0
# 3        5      5        92         1     -1         0       NaN  0
# 4        5      5       198         1     -1         0       NaN  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17     11       977         3     -1         0       NaN  1
# 45207   17     11       456         2     -1         0       NaN  1
# 45208   17     11      1127         5    184         3       2.0  1
# 45209   17     11       508         4     -1         0       NaN  0
# 45210   17     11       361         2    188        11       1.0  0
#
# [45211 rows x 17 columns]

# %%
data1.info()
#in columns 'job' it shows data type object so lets convert it to numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        44923 non-null  object
#  2   marital    45211 non-null  int64
#  3   education  43354 non-null  float64
#  4   default    45211 non-null  int64
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  int64
#  7   loan       45211 non-null  int64
#  8   contact    32191 non-null  float64
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  int64
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   8252 non-null   float64
#  16  y          45211 non-null  int64
# dtypes: float64(3), int64(13), object(1)
# memory usage: 5.9+ MB

# %%
data1['job']=pd.to_numeric(data1['job'],errors='coerce')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        39752 non-null  float64
#  2   marital    45211 non-null  int64
#  3   education  43354 non-null  float64
#  4   default    45211 non-null  int64
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  int64
#  7   loan       45211 non-null  int64
#  8   contact    32191 non-null  float64
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  int64
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   8252 non-null   float64
#  16  y          45211 non-null  int64
# dtypes: float64(4), int64(13)
# memory usage: 5.9 MB

# %%
data1[data1.duplicated()].shape
#there are no duplicated columns or rows
# Out:
# (0, 17)

# %%
#lets cheack for missing values and treat them 
data1.info()
data1.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        39752 non-null  float64
#  2   marital    45211 non-null  int64
#  3   education  43354 non-null  float64
#  4   default    45211 non-null  int64
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  int64
#  7   loan       45211 non-null  int64
#  8   contact    32191 non-null  float64
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  int64
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   8252 non-null   float64
#  16  y          45211 non-null  int64
# dtypes: float64(4), int64(13)
# memory usage: 5.9 MB
# age              0
# job           5459
# marital          0
# education     1857
# default          0
# balance          0
# housing          0
# loan             0
# contact      13020
# day              0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome     36959
# y                0
# dtype: int64

# %% [markdown]
# we can see there are some missing values or na values in columns 'job','education','contact' and 'poutcomes'

# %%
import seaborn as sns
cols = data1.columns
colours = ['#000099','#ffff00']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# here the yellow colour indicates the missing values

# %%
data2=data1.dropna()

# %%
data2.info()
data2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6785 entries, 24064 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        6785 non-null   int64
#  1   job        6785 non-null   float64
#  2   marital    6785 non-null   int64
#  3   education  6785 non-null   float64
#  4   default    6785 non-null   int64
#  5   balance    6785 non-null   int64
#  6   housing    6785 non-null   int64
#  7   loan       6785 non-null   int64
#  8   contact    6785 non-null   float64
#  9   day        6785 non-null   int64
#  10  month      6785 non-null   int64
#  11  duration   6785 non-null   int64
#  12  campaign   6785 non-null   int64
#  13  pdays      6785 non-null   int64
#  14  previous   6785 non-null   int64
#  15  poutcome   6785 non-null   float64
#  16  y          6785 non-null   int64
# dtypes: float64(4), int64(13)
# memory usage: 954.1 KB
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
cols = data1.columns
colours = ['#000099','#ffff00']
sns.heatmap(data2[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %% [markdown]
# we have removed all the null values

# %%
data2.describe()
# Out:
#                age          job      marital    education      default  \
# count  6785.000000  6785.000000  6785.000000  6785.000000  6785.000000
# mean     41.048195     2.865438     0.804274     1.222108     0.006927
# std      11.551714     2.818982     0.609002     0.678194     0.082946
# min      18.000000     0.000000     0.000000     0.000000     0.000000
# 25%      33.000000     0.000000     0.000000     1.000000     0.000000
# 50%      38.000000     3.000000     1.000000     1.000000     0.000000
# 75%      48.000000     4.000000     1.000000     2.000000     0.000000
# max      89.000000    10.000000     2.000000     2.000000     1.000000
#
#             balance      housing         loan      contact          day  \
# count   6785.000000  6785.000000  6785.000000  6785.000000  6785.000000
# mean    1613.456890     0.625203     0.134119     0.077377    14.292262
# std     3215.153103     0.484106     0.340806     0.267208     7.861375
# min    -1884.000000     0.000000     0.000000     0.000000     1.000000
# 25%      171.000000     0.000000     0.000000     0.000000     7.000000
# 50%      614.000000     1.000000     0.000000     0.000000    14.000000
# 75%     1802.000000     1.000000     0.000000     0.000000    20.000000
# max    81204.000000     1.000000     1.000000     1.000000    31.000000
#
#              month     duration     campaign        pdays     previous  \
# count  6785.000000  6785.000000  6785.000000  6785.000000  6785.000000
# mean      5.821665   263.559175     2.084304   222.158585     3.182609
# std       3.107503   239.177517     1.590424   111.224479     4.778476
# min       1.000000     5.000000     1.000000     1.000000     1.000000
# 25%       4.000000   114.000000     1.000000   133.000000     1.000000
# 50%       5.000000   195.000000     2.000000   193.000000     2.000000
# 75%       8.000000   326.000000     2.000000   324.000000     4.000000
# max      12.000000  2219.000000    16.000000   871.000000   275.000000
#
#           poutcome            y
# count  6785.000000  6785.000000
# mean      0.581430     0.227856
# std       0.775819     0.419480
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     0.000000
# max       2.000000     1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['age'].hist()
# Out:
# <AxesSubplot:>

# %%
data2.boxplot(column=['age'])
# Out:
# <AxesSubplot:>

# %%
uf=48+(1.5*(48-33))
uf
# Out:
# 70.5

# %%
lf=48-(1.5*(48-33))
lf
# Out:
# 25.5

# %%
data2[data2.age>uf]
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 40363   83  4.0        1        0.0        0      425        0     0      1.0
# 40368   73  4.0        1        2.0        0      448        0     0      0.0
# 40401   72  7.0        1        2.0        0      132        0     0      0.0
# 40786   83  4.0        1        2.0        0     6236        0     0      0.0
# 40789   71  0.0        1        2.0        0    13297        0     0      0.0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45118   78  4.0        1        0.0        0    14204        0     0      0.0
# 45163   71  4.0        1        1.0        0     2064        0     0      0.0
# 45191   75  4.0        2        2.0        0     3810        1     0      0.0
# 45204   73  4.0        1        1.0        0     2850        0     0      0.0
# 45208   72  4.0        1        1.0        0     5715        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 40363   22      6       883         1    140         1       0.0  1
# 40368   22      6        68         1     90         1       2.0  0
# 40401    1      7       260         2     65         1       2.0  1
# 40786   11      8       155         1    190         2       0.0  0
# 40789   11      8       265         1    190         2       0.0  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45118   26     10       150         1    183         1       1.0  0
# 45163    9     11       379         2     92         3       0.0  0
# 45191   16     11       262         1    183         1       0.0  1
# 45204   17     11       300         1     40         8       0.0  1
# 45208   17     11      1127         5    184         3       2.0  1
#
# [162 rows x 17 columns]

# %%
data3=data2[data2.age<uf]
data3
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 24064   33  6.0        1        1.0        0     3444        1     0      1.0
# 24072   36  0.0        1        2.0        0     2415        1     0      1.0
# 24077   36  0.0        1        2.0        0        0        1     0      1.0
# 24086   44  3.0        1        1.0        0     1324        1     0      1.0
# 24122   26  1.0        0        2.0        0      172        0     1      1.0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45194   59  0.0        1        2.0        0      138        1     1      0.0
# 45195   68  4.0        1        1.0        0     1146        0     0      0.0
# 45199   34  3.0        0        1.0        0     1475        1     0      0.0
# 45201   53  0.0        1        2.0        0      583        0     0      0.0
# 45210   37  2.0        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 24064   21     10       144         1     91         4       0.0  1
# 24072   22     10        73         1     86         4       1.0  0
# 24077   23     10       140         1    143         3       0.0  1
# 24086   25     10       119         1     89         2       1.0  0
# 24122    4     11        21         1    140         4       1.0  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45194   16     11       162         2    187         5       0.0  0
# 45195   16     11       212         1    187         6       2.0  1
# 45199   16     11      1166         3    530        12       1.0  0
# 45201   17     11       226         1    184         4       2.0  1
# 45210   17     11       361         2    188        11       1.0  0
#
# [6623 rows x 17 columns]

# %%
data3.describe()
# Out:
#                age          job      marital    education      default  \
# count  6623.000000  6623.000000  6623.000000  6623.000000  6623.000000
# mean     40.181640     2.833912     0.795108     1.235543     0.007096
# std      10.237946     2.840130     0.609618     0.670444     0.083948
# min      18.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.000000     0.000000     0.000000     1.000000     0.000000
# 50%      38.000000     3.000000     1.000000     1.000000     0.000000
# 75%      47.000000     4.000000     1.000000     2.000000     0.000000
# max      70.000000    10.000000     2.000000     2.000000     1.000000
#
#             balance      housing         loan      contact          day  \
# count   6623.000000  6623.000000  6623.000000  6623.000000  6623.000000
# mean    1553.659369     0.640193     0.137249     0.068700    14.266496
# std     2850.229785     0.479980     0.344136     0.252962     7.852889
# min    -1884.000000     0.000000     0.000000     0.000000     1.000000
# 25%      166.000000     0.000000     0.000000     0.000000     7.000000
# 50%      591.000000     1.000000     0.000000     0.000000    14.000000
# 75%     1761.000000     1.000000     0.000000     0.000000    19.000000
# max    52587.000000     1.000000     1.000000     1.000000    31.000000
#
#              month     duration     campaign        pdays     previous  \
# count  6623.000000  6623.000000  6623.000000  6623.000000  6623.000000
# mean      5.799789   260.789823     2.089234   223.640344     3.182999
# std       3.097736   237.510043     1.599242   111.456785     4.812118
# min       1.000000     5.000000     1.000000     1.000000     1.000000
# 25%       4.000000   113.000000     1.000000   136.000000     1.000000
# 50%       5.000000   193.000000     2.000000   195.000000     2.000000
# 75%       8.000000   323.000000     2.000000   326.000000     4.000000
# max      12.000000  2219.000000    16.000000   871.000000   275.000000
#
#           poutcome            y
# count  6623.000000  6623.000000
# mean      0.569681     0.221048
# std       0.768961     0.414984
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     0.000000
# max       2.000000     1.000000

# %%
data3['pdays'].hist()
# Out:
# <AxesSubplot:>

# %%
data3.boxplot(column=['pdays'])
# Out:
# <AxesSubplot:>

# %%
uf_pdays=326+(1.5*(326-136))
uf_pdays
# Out:
# 611.0

# %%
lf_pdays=326-(1.5*(326-136))
lf_pdays
# Out:
# 41.0

# %%
data3[data3.pdays>uf_pdays]
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 43034   46  0.0        1        2.0        0      349        0     0      0.0
# 43404   54  1.0        1        1.0        0     2102        1     0      0.0
# 43507   39  3.0        0        1.0        0     1672        1     0      0.0
# 43964   32  0.0        1        2.0        0      913        1     0      0.0
# 44038   31  0.0        0        2.0        0     1539        1     0      0.0
# 44089   37  1.0        1        1.0        0      432        1     0      0.0
# 44287   37  1.0        1        1.0        0     1707        1     0      0.0
# 44446   32  0.0        0        2.0        0     1077        0     0      0.0
# 44496   33  0.0        1        2.0        0     1514        0     0      0.0
# 44530   34  3.0        1        1.0        0      320        1     0      0.0
# 44570   60  6.0        1        2.0        0     4256        1     0      0.0
# 44667   48  0.0        1        2.0        0     1204        0     0      0.0
# 44698   34  1.0        1        1.0        0      384        1     0      0.0
# 44754   33  8.0        0        1.0        0     2066        0     1      0.0
# 44798   38  0.0        1        2.0        0     1477        0     0      0.0
# 44815   60  4.0        1        1.0        0      975        0     0      0.0
# 44829   37  0.0        2        2.0        0      488        1     0      0.0
# 44858   31  9.0        1        1.0        0      243        1     0      0.0
# 44864   46  0.0        1        2.0        0     7485        0     0      0.0
# 44974   39  0.0        1        2.0        0      839        0     1      0.0
# 45036   28  0.0        1        2.0        0     1918        0     0      0.0
# 45037   45  0.0        0        2.0        0     2048        1     0      0.0
# 45120   32  1.0        1        1.0        0     1547        0     0      0.0
# 45146   49  8.0        2        2.0        0      780        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 43034   15      2       295         2    616         1       0.0  1
# 43404    5      4       547         1    626         2       0.0  1
# 43507   20      4       462         1    648         1       0.0  1
# 43964   23      6       883         1    674         4       0.0  0
# 44038   30      6       107         2    756         2       1.0  0
# 44089    6      7       386         3    776        55       0.0  1
# 44287   26      7       546         2    784         3       0.0  1
# 44446    5      8       200         1    717         4       0.0  0
# 44496   10      8       447         1    728         2       0.0  1
# 44530   12      8       352         1    828         2       0.0  1
# 44570   16      8       239         3    761         1       1.0  1
# 44667    3      9       116         2    760         1       1.0  0
# 44698    6      9       127         2    831         1       1.0  0
# 44754    9      9       305         1    749         2       0.0  1
# 44798   15      9       385         3    769         2       0.0  1
# 44815   16      9       303         1    792         1       0.0  1
# 44829   17      9       328         1    854         2       0.0  1
# 44858   23      9       305         2    842         1       0.0  1
# 44864   23      9       145         1    779         2       0.0  0
# 44974   11     10       365         2    774        11       0.0  0
# 45036   18     10       333         1    616         1       0.0  0
# 45037   18     10       310         1    804         1       0.0  1
# 45120   26     10       289         1    805         4       1.0  1
# 45146    8     11       148         1    871         2       0.0  0

# %%
data4=data3[data3.pdays<uf_pdays]
data4
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 24064   33  6.0        1        1.0        0     3444        1     0      1.0
# 24072   36  0.0        1        2.0        0     2415        1     0      1.0
# 24077   36  0.0        1        2.0        0        0        1     0      1.0
# 24086   44  3.0        1        1.0        0     1324        1     0      1.0
# 24122   26  1.0        0        2.0        0      172        0     1      1.0
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45194   59  0.0        1        2.0        0      138        1     1      0.0
# 45195   68  4.0        1        1.0        0     1146        0     0      0.0
# 45199   34  3.0        0        1.0        0     1475        1     0      0.0
# 45201   53  0.0        1        2.0        0      583        0     0      0.0
# 45210   37  2.0        1        1.0        0     2971        0     0      0.0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 24064   21     10       144         1     91         4       0.0  1
# 24072   22     10        73         1     86         4       1.0  0
# 24077   23     10       140         1    143         3       0.0  1
# 24086   25     10       119         1     89         2       1.0  0
# 24122    4     11        21         1    140         4       1.0  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45194   16     11       162         2    187         5       0.0  0
# 45195   16     11       212         1    187         6       2.0  1
# 45199   16     11      1166         3    530        12       1.0  0
# 45201   17     11       226         1    184         4       2.0  1
# 45210   17     11       361         2    188        11       1.0  0
#
# [6599 rows x 17 columns]

# %%
data4.describe()
# Out:
#                age          job      marital    education      default  \
# count  6599.000000  6599.000000  6599.000000  6599.000000  6599.000000
# mean     40.183058     2.837248     0.794817     1.234278     0.007122
# std      10.242193     2.839530     0.609884     0.670674     0.084099
# min      18.000000     0.000000     0.000000     0.000000     0.000000
# 25%      32.000000     0.000000     0.000000     1.000000     0.000000
# 50%      38.000000     3.000000     1.000000     1.000000     0.000000
# 75%      47.000000     4.000000     1.000000     2.000000     0.000000
# max      70.000000    10.000000     2.000000     2.000000     1.000000
#
#             balance      housing         loan      contact          day  \
# count   6599.000000  6599.000000  6599.000000  6599.000000  6599.000000
# mean    1553.652220     0.640703     0.137445     0.068950    14.263676
# std     2853.972065     0.479831     0.344343     0.253388     7.854014
# min    -1884.000000     0.000000     0.000000     0.000000     1.000000
# 25%      164.500000     0.000000     0.000000     0.000000     7.000000
# 50%      589.000000     1.000000     0.000000     0.000000    14.000000
# 75%     1761.000000     1.000000     0.000000     0.000000    19.000000
# max    52587.000000     1.000000     1.000000     1.000000    31.000000
#
#              month     duration     campaign        pdays     previous  \
# count  6599.000000  6599.000000  6599.000000  6599.000000  6599.000000
# mean      5.791938   260.537657     2.091226   221.701773     3.178209
# std       3.097910   237.690236     1.601241   106.824450     4.776585
# min       1.000000     5.000000     1.000000     1.000000     1.000000
# 25%       4.000000   113.000000     1.000000   135.500000     1.000000
# 50%       5.000000   192.000000     2.000000   195.000000     2.000000
# 75%       8.000000   323.000000     2.000000   325.000000     4.000000
# max      12.000000  2219.000000    16.000000   603.000000   275.000000
#
#           poutcome            y
# count  6599.000000  6599.000000
# mean      0.570996     0.219579
# std       0.769659     0.413993
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     0.000000
# max       2.000000     1.000000

# %%
data4.balance=data4.balance.apply(lambda v: (v-data4.balance.min())/(data4.balance.max()-data4.balance.min()))
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data4
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 24064   33  6.0        1        1.0        0  0.097814        1     0
# 24072   36  0.0        1        2.0        0  0.078923        1     0
# 24077   36  0.0        1        2.0        0  0.034587        1     0
# 24086   44  3.0        1        1.0        0  0.058894        1     0
# 24122   26  1.0        0        2.0        0  0.037745        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 45194   59  0.0        1        2.0        0  0.037121        1     1
# 45195   68  4.0        1        1.0        0  0.055626        0     0
# 45199   34  3.0        0        1.0        0  0.061666        1     0
# 45201   53  0.0        1        2.0        0  0.045290        0     0
# 45210   37  2.0        1        1.0        0  0.089130        0     0
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 24064      1.0   21     10       144         1     91         4       0.0  1
# 24072      1.0   22     10        73         1     86         4       1.0  0
# 24077      1.0   23     10       140         1    143         3       0.0  1
# 24086      1.0   25     10       119         1     89         2       1.0  0
# 24122      1.0    4     11        21         1    140         4       1.0  0
# ...        ...  ...    ...       ...       ...    ...       ...       ... ..
# 45194      0.0   16     11       162         2    187         5       0.0  0
# 45195      0.0   16     11       212         1    187         6       2.0  1
# 45199      0.0   16     11      1166         3    530        12       1.0  0
# 45201      0.0   17     11       226         1    184         4       2.0  1
# 45210      0.0   17     11       361         2    188        11       1.0  0
#
# [6599 rows x 17 columns]

# %%
data4.duration=data4.duration.apply(lambda v: (v-data4.duration.min())/(data4.duration.max()-data2.duration.min()))
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data4
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 24064   33  6.0        1        1.0        0  0.097814        1     0
# 24072   36  0.0        1        2.0        0  0.078923        1     0
# 24077   36  0.0        1        2.0        0  0.034587        1     0
# 24086   44  3.0        1        1.0        0  0.058894        1     0
# 24122   26  1.0        0        2.0        0  0.037745        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 45194   59  0.0        1        2.0        0  0.037121        1     1
# 45195   68  4.0        1        1.0        0  0.055626        0     0
# 45199   34  3.0        0        1.0        0  0.061666        1     0
# 45201   53  0.0        1        2.0        0  0.045290        0     0
# 45210   37  2.0        1        1.0        0  0.089130        0     0
#
#        contact  day  month  duration  campaign  pdays  previous  poutcome  y
# 24064      1.0   21     10  0.062782         1     91         4       0.0  1
# 24072      1.0   22     10  0.030714         1     86         4       1.0  0
# 24077      1.0   23     10  0.060976         1    143         3       0.0  1
# 24086      1.0   25     10  0.051491         1     89         2       1.0  0
# 24122      1.0    4     11  0.007227         1    140         4       1.0  0
# ...        ...  ...    ...       ...       ...    ...       ...       ... ..
# 45194      0.0   16     11  0.070912         2    187         5       0.0  0
# 45195      0.0   16     11  0.093496         1    187         6       2.0  1
# 45199      0.0   16     11  0.524390         3    530        12       1.0  0
# 45201      0.0   17     11  0.099819         1    184         4       2.0  1
# 45210      0.0   17     11  0.160795         2    188        11       1.0  0
#
# [6599 rows x 17 columns]

# %%
data4.pdays=data4.pdays.apply(lambda v: (v-data4.pdays.min())/(data4.pdays.max()-data2.pdays.min()))
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data4
# Out:
#        age  job  marital  education  default   balance  housing  loan  \
# 24064   33  6.0        1        1.0        0  0.097814        1     0
# 24072   36  0.0        1        2.0        0  0.078923        1     0
# 24077   36  0.0        1        2.0        0  0.034587        1     0
# 24086   44  3.0        1        1.0        0  0.058894        1     0
# 24122   26  1.0        0        2.0        0  0.037745        0     1
# ...    ...  ...      ...        ...      ...       ...      ...   ...
# 45194   59  0.0        1        2.0        0  0.037121        1     1
# 45195   68  4.0        1        1.0        0  0.055626        0     0
# 45199   34  3.0        0        1.0        0  0.061666        1     0
# 45201   53  0.0        1        2.0        0  0.045290        0     0
# 45210   37  2.0        1        1.0        0  0.089130        0     0
#
#        contact  day  month  duration  campaign     pdays  previous  poutcome  \
# 24064      1.0   21     10  0.062782         1  0.149502         4       0.0
# 24072      1.0   22     10  0.030714         1  0.141196         4       1.0
# 24077      1.0   23     10  0.060976         1  0.235880         3       0.0
# 24086      1.0   25     10  0.051491         1  0.146179         2       1.0
# 24122      1.0    4     11  0.007227         1  0.230897         4       1.0
# ...        ...  ...    ...       ...       ...       ...       ...       ...
# 45194      0.0   16     11  0.070912         2  0.308970         5       0.0
# 45195      0.0   16     11  0.093496         1  0.308970         6       2.0
# 45199      0.0   16     11  0.524390         3  0.878738        12       1.0
# 45201      0.0   17     11  0.099819         1  0.303987         4       2.0
# 45210      0.0   17     11  0.160795         2  0.310631        11       1.0
#
#        y
# 24064  1
# 24072  0
# 24077  1
# 24086  0
# 24122  0
# ...   ..
# 45194  0
# 45195  1
# 45199  0
# 45201  1
# 45210  0
#
# [6599 rows x 17 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
x=data4.iloc[:,0:15]
y=data4.iloc[:,16]

# %%
classifier = LogisticRegression()
classifier.fit(x,y)
# Out:
# C:\Users\abc\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = classifier.predict(x)

# %%
y_pred_df= pd.DataFrame({'actual': y,
                         'predicted_prob': classifier.predict(x)})

# %%
y_pred_df
# Out:
#        actual  predicted_prob
# 24064       1               0
# 24072       0               0
# 24077       1               0
# 24086       0               0
# 24122       0               0
# ...       ...             ...
# 45194       0               0
# 45195       1               0
# 45199       0               1
# 45201       1               0
# 45210       0               0
#
# [6599 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y,y_pred)
print (confusion_matrix)
# Out:
# [[4908  242]
#  [1030  419]]

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y, classifier.predict_proba (x)[:,1])

auc = roc_auc_score(y, y_pred)

import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='red', label='logit model ( area  = %0.2f)'%auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %%
auc
# Out:
# 0.6210873250383592

# %% [markdown]
# As we can my accuracy or auc is 0.621 which is greater than 0.5 so i assume my model is a good model
